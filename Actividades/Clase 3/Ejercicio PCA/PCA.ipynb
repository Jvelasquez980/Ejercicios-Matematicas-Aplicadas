# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
# Leer imagen en png y transformar a escala de grises
open_cv_image = cv2.imread('image.png')
# Out:
# [ WARN:0@0.031] global loadsave.cpp:278 findDecoder imread_('image.png'): can't open/read file: check file path/integrity
